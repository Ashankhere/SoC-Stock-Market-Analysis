# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("GOOG_train.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-06-10  719.469971  725.890015  716.429993  719.409973  719.409973
# 1  2016-06-13  716.510010  725.440002  716.510010  718.359985  718.359985
# 2  2016-06-14  716.479980  722.469971  713.119995  718.270020  718.270020
# 3  2016-06-15  719.000000  722.979980  717.309998  718.919983  718.919983
# 4  2016-06-16  714.909973  716.650024  703.260010  710.359985  710.359985
#
#     Volume
# 0  1216400
# 1  1258900
# 2  1306100
# 3  1214500
# 4  1982500

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean   1212.412150  1224.570048  1201.347431  1213.457483  1213.457483
# std     379.454923   384.609149   375.747847   380.308660   380.308660
# min     671.000000   672.299988   663.283997   668.260010   668.260010
# 25%     957.377518   963.404984   950.767502   958.119980   958.119980
# 50%    1130.574951  1142.984985  1117.374024  1132.005005  1132.005005
# 75%    1357.785034  1372.300995  1346.885010  1358.957519  1358.957519
# max    2499.500000  2505.000000  2487.330078  2491.399902  2491.399902
#
#              Volume
# count  1.258000e+03
# mean   1.610740e+06
# std    7.031610e+05
# min    3.468000e+05
# 25%    1.184300e+06
# 50%    1.423200e+06
# 75%    1.823950e+06
# max    6.207000e+06

# %%
df.Date= pd.to_datetime(df.Date)

# %%
df2 =df.set_index('Date')
df2
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-06-10   719.469971   725.890015   716.429993   719.409973   719.409973
# 2016-06-13   716.510010   725.440002   716.510010   718.359985   718.359985
# 2016-06-14   716.479980   722.469971   713.119995   718.270020   718.270020
# 2016-06-15   719.000000   722.979980   717.309998   718.919983   718.919983
# 2016-06-16   714.909973   716.650024   703.260010   710.359985   710.359985
# ...                 ...          ...          ...          ...          ...
# 2021-06-03  2395.020020  2409.745117  2382.830078  2404.610107  2404.610107
# 2021-06-04  2422.520020  2453.858887  2417.770020  2451.760010  2451.760010
# 2021-06-07  2451.320068  2468.000000  2441.072998  2466.090088  2466.090088
# 2021-06-08  2479.899902  2494.495117  2468.239990  2482.850098  2482.850098
# 2021-06-09  2499.500000  2505.000000  2487.330078  2491.399902  2491.399902
#
#              Volume
# Date
# 2016-06-10  1216400
# 2016-06-13  1258900
# 2016-06-14  1306100
# 2016-06-15  1214500
# 2016-06-16  1982500
# ...             ...
# 2021-06-03   917300
# 2021-06-04  1297400
# 2021-06-07  1192500
# 2021-06-08  1253000
# 2021-06-09  1006300
#
# [1258 rows x 6 columns]

# %%
#df2['Volume'] = df2['Volume'].str.replace(',', '').astype(float)    #unique to the google_test_data.csv
#df2['Close'] = df2['Close'].str.replace(',', '').astype(float)

# %%
df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2016-06-10 to 2021-06-09
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Adj Close  1258 non-null   float64
#  5   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.8 KB
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-06-10   719.469971   725.890015   716.429993   719.409973   719.409973
# 2016-06-13   716.510010   725.440002   716.510010   718.359985   718.359985
# 2016-06-14   716.479980   722.469971   713.119995   718.270020   718.270020
# 2016-06-15   719.000000   722.979980   717.309998   718.919983   718.919983
# 2016-06-16   714.909973   716.650024   703.260010   710.359985   710.359985
# ...                 ...          ...          ...          ...          ...
# 2021-06-03  2395.020020  2409.745117  2382.830078  2404.610107  2404.610107
# 2021-06-04  2422.520020  2453.858887  2417.770020  2451.760010  2451.760010
# 2021-06-07  2451.320068  2468.000000  2441.072998  2466.090088  2466.090088
# 2021-06-08  2479.899902  2494.495117  2468.239990  2482.850098  2482.850098
# 2021-06-09  2499.500000  2505.000000  2487.330078  2491.399902  2491.399902
#
#              Volume
# Date
# 2016-06-10  1216400
# 2016-06-13  1258900
# 2016-06-14  1306100
# 2016-06-15  1214500
# 2016-06-16  1982500
# ...             ...
# 2021-06-03   917300
# 2021-06-04  1297400
# 2021-06-07  1192500
# 2021-06-08  1253000
# 2021-06-09  1006300
#
# [1258 rows x 6 columns]

# %%
plt.figure(figsize=(20,5),dpi=300)
plt.plot(df2.Close,label='Close')
plt.plot(df2.Open,label='Open')
plt.plot(df2.High,label='High')
plt.plot(df2.Low,label='Low')
plt.legend()
plt.show()        #data wrong close > high & open

# %%
plt.figure(figsize=(20,5))
plt.bar(x=df2.index,height=df2['Volume'])
plt.title('Volume Traded')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.subplot(3, 2, 1)
sns.barplot(x=df2.index,y=df2['Open'])
plt.subplot(3, 2, 2)
sns.barplot(x=df2.index,y=df2['High'])
plt.subplot(3, 2, 3)
sns.barplot(x=df2.index,y=df2['Low'])
plt.subplot(3, 2, 4)
sns.barplot(x=df2.index,y=df2['Close'])
plt.subplot(3, 1, 3)
sns.barplot(x=df2.index,y=df2['Volume'])

plt.show()

# %% [markdown]
# # Regression :

# %%
x = df2.iloc[:,[0,1,2,4]].values  # [Open,High,Low,Volume]
x
y = df2["Close"]
y
# Out:
# Date
# 2016-06-10     719.409973
# 2016-06-13     718.359985
# 2016-06-14     718.270020
# 2016-06-15     718.919983
# 2016-06-16     710.359985
#                  ...
# 2021-06-03    2404.610107
# 2021-06-04    2451.760010
# 2021-06-07    2466.090088
# 2021-06-08    2482.850098
# 2021-06-09    2491.399902
# Name: Close, Length: 1258, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(x_train)
print(scaler)
x_train_scaled = scaler.transform(x_train)
x_train_scaled
# Out:
# StandardScaler()
# array([[-9.78602273e-01, -9.78074588e-01, -9.97250210e-01,
#         -1.00878218e+00],
#        [-3.46067890e-01, -3.15488660e-01, -3.36547800e-01,
#         -3.06233438e-01],
#        [-1.75804479e-02, -1.75262321e-02,  9.00785664e-03,
#         -6.63644733e-04],
#        ...,
#        [ 2.78755953e+00,  2.74417100e+00,  2.77203125e+00,
#          2.74909950e+00],
#        [ 8.09446210e-02,  8.32836226e-02,  1.08312602e-01,
#          1.09515079e-01],
#        [-2.15156950e-01, -1.96371209e-01, -1.88357586e-01,
#         -1.74817483e-01]])

# %%
scaler = StandardScaler().fit(x_test)
print(scaler)
x_test_scaled = scaler.transform(x_test)
x_test_scaled
# Out:
# StandardScaler()
# array([[-1.40355424, -1.41629366, -1.43920617, -1.44937476],
#        [-0.45412694, -0.459503  , -0.45402554, -0.46946004],
#        [-1.23850251, -1.24391125, -1.22802928, -1.24222608],
#        ...,
#        [-0.15445943, -0.18001148, -0.16975385, -0.19319095],
#        [-1.27967886, -1.25496079, -1.26313682, -1.24387432],
#        [-0.31913784, -0.32890386, -0.30118557, -0.31625197]])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test_scaled)

# %%
sr = pd.Series(y_test)
sr = sr.to_frame()

plt.figure(figsize=(20,5),dpi=300)
plt.scatter(x=sr.index,y=sr['Close'],label='Actual')
plt.scatter(x=sr.index,y=y_pred,label='Predicted')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 29.712748420369298

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9937604738327982
